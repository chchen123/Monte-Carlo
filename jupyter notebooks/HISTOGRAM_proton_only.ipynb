# %%
'''
This script plots histograms of objective function values fitting over 7000 events classified using CNN models.
'''

# %%
import h5py
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# **RUN_0130**

# %%
full = h5py.File('/home/chen/ar46/MonteCarlo/chi_values/run_0130.h5', 'r')
#orig_data = h5py.File('/home/chen/ar46/clean_events/clean_run_0130.h5', 'r')
proton_MC = h5py.File('/home/chen/ar46/MonteCarlo/proton_chi_values/run_0130_proton.h5', 'r')
#proton_DE = h5py.File('/home/chen/ar46/DiffEvolution/run_0130_proton.h5', 'r')
#proton_BH = h5py.File('/home/chen/ar46/Basinhopping/run_0130_proton.h5', 'r')
#MC = h5py.File('/home/chen/ar46/MonteCarlo/chi_values/run_0130.h5', 'r')
#DE = h5py.File('/home/chen/ar46/DiffEvolution/chi_values/with_cleaning/run_0130.h5', 'r')
#BH = h5py.File('/home/chen/ar46/Basinhopping/chi_values/run_0130.h5', 'r')

#data set's names are: position, energy, total, vertex
#dataset_name = '/total'
#proton_MC_total = proton_MC[dataset_name]
#print("# of proton events successfully processed: " + str(len(proton_MC_total)))

#dataset_name = '/position'
#proton_MC_position = proton_MC[dataset_name]
#print("# of proton events successfully processed: " + str(len(proton_MC_position)))

#dataset_name = '/energy'
#proton_MC_energy = proton_MC[dataset_name]
#print("# of proton events successfully processed: " + str(len(proton_MC_energy)))

#dataset_name = '/vertex'
#proton_MC_vertex = proton_MC[dataset_name]
#print("# of proton events successfully processed: " + str(len(proton_MC_vertex)))

dataset_name = '/total'
proton_MC_total = full[dataset_name]
print("# of proton events successfully processed: " + str(len(proton_MC_total)))

dataset_name = '/proton'
MC_total_full = full[dataset_name]
print("# of proton events successfully processed: " + str(len(MC_total_full)))

#dataset_name = '/total'
#evt_BH = BH[dataset_name]
#print("# of clean events successfully processed - BH: " + str(len(evt_BH)))

#dataset_name = '/total'
#evt_DE = DE[dataset_name]
#print("# of clean events successfully processed - DE: " + str(len(evt_DE)))

#dataset_name = '/total'
#proton_MC_full = proton_MC[dataset_name]
#print("# of proton events successfully processed: " + str(len(proton_MC_full)))

#dataset_name = '/total'
#proton_DE_full = proton_DE[dataset_name]
#print("# of proton events successfully processed: " + str(len(proton_DE_full)))

#dataset_name = '/total'
#proton_BH_full = proton_BH[dataset_name]
#print("# of proton events successfully processed: " + str(len(proton_BH_full)))
# Out:
# # of proton events successfully processed: 668
# # of proton events successfully processed: 668

# %%
#creating arrays that contain all the objective function values for all the runs, fitted with each method

monte_carlo = np.empty((0,0))
#proton_DE = np.empty((0,0))
#proton_BH = np.empty((0,0))
#proton_MC = np.empty((0,0))
#differential_evolution = np.empty((0,0))
#basinhopping = np.empty((0,0))

MC_total = np.empty((0,0))
MC_position = np.empty((0,0))
MC_energy = np.empty((0,0))
MC_vertex = np.empty((0,0))

#        differential_evolution = np.append(differential_evolution, np.array(evt_DE[str(i)]))
#        basinhopping = np.append(basinhopping, np.array(evt_BH[str(i)]))

#    except Exception:
#        continue

for i in range(1002):
    try:
        monte_carlo = np.append(monte_carlo, np.array(MC_total_full[str(i)]))
    except Exception:  
        continue    
        
for i in range(1002):
    try:
        MC_total = np.append(MC_total, np.array(proton_MC_total[str(i)]))
        #MC_energy = np.append(MC_energy, np.array(proton_MC_energy[str(i)]))
        #MC_position = np.append(MC_position, np.array(proton_MC_position[str(i)]))
        #MC_vertex = np.append(MC_vertex, np.array(proton_MC_vertex[str(i)]))
       # proton_BH = np.append(proton_BH, np.array(proton_BH_full[str(i)]))
       # proton_MC = np.append(proton_MC, np.array(proton_MC_full[str(i)]))
       # proton_DE = np.append(proton_DE, np.array(proton_DE_full[str(i)]))
    except Exception:
        continue    
print(len(monte_carlo))
#print(len(proton_MC))
# Out:
# 200

# %%
plt.hist(monte_carlo, label='All Events', bins=50, color='blue',range=(0,120),alpha=0.5) 
plt.hist(MC_total, label='Proton Events', bins=50, color='orange',range=(0,120),alpha=0.5)
#plt.hist(basinhopping, label='less cut', bins=50, color='cyan',range=(0,40))
##plt.hist(proton_BH, label='Cleaned Data', bins=50, color='orange',range=(0,120))
#plt.hist(basinhopping, label='less cut', bins=50, color='cyan',range=(0,40))
#plt.hist(proton_DE, label='more cut', bins=50, color='orange',range=(0,40))
plt.legend(loc=1)
plt.title('RUN_0130 - Total Objective Function Value')
plt.xlabel('Goodness of Fit')
plt.ylabel('Number of Events')

plt.show()

plt.hist(MC_position, label='Position Objective Function Value', bins=50, color='orange',range=(0,120))
plt.legend(loc=1)
plt.title('RUN_0130 - Position Objective Function Value')
plt.xlabel('Goodness of Fit')
plt.ylabel('Number of Events')
plt.show()

plt.hist(MC_energy, label='Energy Objective Function Value', bins=50, color='orange',range=(0,120))
plt.legend(loc=1)
plt.title('RUN_0130 - Energy Objective Function Value')
plt.xlabel('Goodness of Fit')
plt.ylabel('Number of Events')
plt.show()

plt.hist(MC_vertex, label='Vertex Position Objective Function Value', bins=50, color='orange',range=(0,120))
plt.legend(loc=1)
plt.title('RUN_0130 - Vertex Position Objective Function Value')
plt.xlabel('Goodness of Fit')
plt.ylabel('Number of Events')
plt.show()

# %% [markdown]
# ## Differential Evolution Cleaned Events

# %%
plt.rcParams["axes.labelsize"] = 16
plt.rcParams["axes.titlesize"] = 16
plt.rcParams["xtick.labelsize"] = 16
plt.rcParams["ytick.labelsize"] = 16
plt.rcParams.update({'font.size': 14})
DE = np.loadtxt("/home/chen/DE_run_0130.txt")
DE_time = np.loadtxt("/home/chen/DE_run_0130_time.txt")
DE_avg = sum(DE)/len(DE)
DE_avgtime = sum(DE_time)/len(DE_time)
print(DE_avg)
print(DE_avgtime)
print(len(DE))
plt.hist(DE, label='Cleaned Tracks', bins=50, color='green',range=(0,140)) 
plt.legend(loc=1)
plt.title('Differential Evolution Fitting Results')
plt.xlabel('Goodness of Fit')
plt.ylabel('Number of Events')
plt.show()
# Out:
# 35.32510260971449
# 152.73188907033173
# 7240

# %% [markdown]
# ## Differential Evolution Original Events

# %%
plt.rcParams["axes.labelsize"] = 16
plt.rcParams["axes.titlesize"] = 16
plt.rcParams["xtick.labelsize"] = 16
plt.rcParams["ytick.labelsize"] = 16
plt.rcParams.update({'font.size': 14})
DE = np.loadtxt("/home/chen/DE_run_0130_uncleaned.txt")
DE_time = np.loadtxt("/home/chen/DE_run_0130_time_uncleaned.txt")
DE_avg = sum(DE)/len(DE)
DE_avgtime = sum(DE_time)/len(DE_time)
print(DE_avg)
print(DE_avgtime)
print(len(DE))
plt.hist(DE, label='Original Tracks', bins=50, color='orange',range=(0,140)) 
plt.legend(loc=1)
plt.title('Differential Evolution Fitting Results')
plt.xlabel('Goodness of Fit')
plt.ylabel('Number of Events')
plt.show()
# Out:
# 70.87464868267588
# 110.51647169475761
# 10352

# %% [markdown]
# ## Basin Hopping Cleaned Events

# %%
plt.rcParams["axes.labelsize"] = 16
plt.rcParams["axes.titlesize"] = 16
plt.rcParams["xtick.labelsize"] = 16
plt.rcParams["ytick.labelsize"] = 16
plt.rcParams.update({'font.size': 14})
BH = np.loadtxt("/home/chen/BH_run_0130.txt")
BH_time = np.loadtxt("/home/chen/BH_run_0130_time.txt")
BH_avg = sum(BH)/len(BH)
BH_avgtime = sum(BH_time)/len(BH_time)
print(BH_avg)
print(BH_avgtime)
print(len(BH))
plt.hist(BH, label='Cleaned Tracks', bins=50, color='green',range=(0,140)) 
plt.legend(loc=1)
plt.title('RUN_0130 - Basin Hopping Fitting Results')
plt.xlabel('Goodness of Fit')
plt.ylabel('Number of Events')
plt.show()

# %% [markdown]
# ## Basin Hopping Original Events

# %%
plt.rcParams["axes.labelsize"] = 16
plt.rcParams["axes.titlesize"] = 16
plt.rcParams["xtick.labelsize"] = 16
plt.rcParams["ytick.labelsize"] = 16
plt.rcParams.update({'font.size': 14})
BH = np.loadtxt("/home/chen/BH_run_0130_uncleaned.txt")
BH_time = np.loadtxt("/home/chen/BH_run_0130_time_uncleaned.txt")
BH_avg = sum(BH)/len(BH)
BH_avgtime = sum(BH_time)/len(BH_time)
print(BH_avg)
print(BH_avgtime)
print(len(BH))
plt.hist(BH, label='Original Tracks', bins=50, color='orange',range=(0,140)) 
plt.legend(loc=1)
plt.title('RUN_0130 - Basin Hopping Fitting Results')
plt.xlabel('Goodness of Fit')
plt.ylabel('Number of Events')
plt.show()
# Out:
# 78.0567517792539
# 128.55832317594945
# 9126

# %% [markdown]
# ## Monte Carlo Cleaned Events

# %%
plt.rcParams["axes.labelsize"] = 16
plt.rcParams["axes.titlesize"] = 16
plt.rcParams["xtick.labelsize"] = 16
plt.rcParams["ytick.labelsize"] = 16
plt.rcParams.update({'font.size': 14})
MC = np.loadtxt("/home/chen/MonteCarlo130Proton_cleaned.txt")
MC_avg = sum(MC)/len(MC)
print(len(MC))
print(MC_avg)
plt.hist(MC, label='Cleaned Tracks', bins=50, color='green',range=(0,140)) 
plt.legend(loc=1)
plt.title('RUN_0130 - Monte Carlo Fitting Results')
plt.xlabel('Goodness of Fit')
plt.ylabel('Number of Events')
plt.show()
# Out:
# 7150
# 59.20861311062243

# %% [markdown]
# ## Monte Carlo Original Events

# %%
plt.rcParams["axes.labelsize"] = 16
plt.rcParams["axes.titlesize"] = 16
plt.rcParams["xtick.labelsize"] = 16
plt.rcParams["ytick.labelsize"] = 16
plt.rcParams.update({'font.size': 14})
MC = np.loadtxt("/home/chen/MonteCarlo130Proton.txt")
MC_avg = sum(MC)/len(MC)
print(len(MC))
print(MC_avg)
plt.hist(MC, label='Original Tracks', bins=50, color='orange',range=(0,140)) 
plt.legend(loc=1)
plt.title('RUN_0130 - Monte Carlo Fitting Results')
plt.xlabel('Goodness of Fit')
plt.ylabel('Number of Events')
plt.show()
#time is 7.5708s per event
# Out:
# 9134
# 97.82124851118384
